# %%
import numpy as np 
import pandas as pd 
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
def ReadData(sf):
    print("Baca file :",sf)
    df = pd.read_csv(sf,header=None)
    df = np.array(df)
    Xfungsi = df[2:,1:2]
    Xirama = df[2:,2:3]
    Xgatra = df[2:,4:5]
    XNote1 = df[2:,5:6]
    XNote2 = df[2:,7:8]
    XNote3 = df[2:,9:10]
    XNote4 = df[2:,11:12]
    XSelehBaris = df[2:,14:15]
    XSelehAkhir = df[2:,15:16]
    XPathet = df[2:,16:17]
   
    YBarung1 = df[2:,22:23]
    YBarung5 = df[2:,26:27]  
    YBarung9 = df[2:,30:31]    
    YBarung13 = df[2:,34:35]   
    YBarung17 = df[2:,38:39]    
    YBarung21 = df[2:,42:43]   
    YBarung25 = df[2:,46:47]    
    YBarung29 = df[2:,50:51]
   
    YPenerus1 = df[2:,54:55]
    YPenerus2 = df[2:,55:56]  
    YPenerus3 = df[2:,56:57]    
    YPenerus4 = df[2:,57:58]   
    YPenerus5 = df[2:,58:59]    
    YPenerus6 = df[2:,59:60]   
    YPenerus7 = df[2:,60:61]    
    YPenerus8 = df[2:,61:62]   
    YPenerus9 = df[2:,62:63]
    YPenerus10 = df[2:,63:64]  
    YPenerus11 = df[2:,64:65]    
    YPenerus12 = df[2:,65:66]   
    YPenerus13 = df[2:,66:67]    
    YPenerus14 = df[2:,67:68]   
    YPenerus15 = df[2:,68:69]    
    YPenerus16 = df[2:,69:70]
    return Xfungsi,Xirama,Xgatra,XNote1,XNote2,XNote3,XNote4,XSelehBaris,XSelehAkhir,XPathet,YBarung1,YBarung5,YBarung9,YBarung13,YBarung17,YBarung21,YBarung25,YBarung29,YPenerus1,YPenerus2,YPenerus3,YPenerus4,YPenerus5,YPenerus6,YPenerus7,YPenerus8,YPenerus9,YPenerus10,YPenerus11,YPenerus12,YPenerus13,YPenerus14,YPenerus15,YPenerus16

# %%
sf='databinerSemua.csv'

Xfungsi,Xirama,Xgatra,XNote1,XNote2,XNote3,XNote4,XSelehBaris,XSelehAkhir,XPathet,YBarung1,YBarung5,YBarung9,YBarung13,YBarung17,YBarung21,YBarung25,YBarung29,YPenerus1,YPenerus2,YPenerus3,YPenerus4,YPenerus5,YPenerus6,YPenerus7,YPenerus8,YPenerus9,YPenerus10,YPenerus11,YPenerus12,YPenerus13,YPenerus14,YPenerus15,YPenerus16=ReadData(sf)
# Out:
# Baca file : databinerSemua.csv

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

encoderXfungsi = LabelEncoder()
encodedXfungsi = encoderXfungsi.fit(Xfungsi)
encodedXfungsi = encodedXfungsi.transform(Xfungsi)
one_hot_labelsXfungsi = to_categorical(encodedXfungsi)
# X2_enc=encodedX2.reshape(116,1)

encoderXirama = LabelEncoder()
encodedXirama = encoderXirama.fit(Xirama)
encodedXirama = encodedXirama.transform(Xirama)
one_hot_labelsXirama = to_categorical(encodedXirama)
# X1_enc=encodedX1.reshape(116,1)

encoderXSelehBaris = LabelEncoder()
encodedXSelehBaris = encoderXSelehBaris.fit(XSelehBaris)
encodedXSelehBaris = encodedXSelehBaris.transform(XSelehBaris)
one_hot_labelsXSelehBaris= to_categorical(encodedXSelehBaris)
# X2_enc=encodedX2.reshape(116,1)

encoderXSelehAkhir = LabelEncoder()
encodedXSelehAkhir = encoderXSelehAkhir.fit(XSelehAkhir)
encodedXSelehAkhir = encodedXSelehAkhir.transform(XSelehAkhir)
one_hot_labelsXSelehAkhir = to_categorical(encodedXSelehAkhir)
# X2_enc=encodedX2.reshape(116,1)

encoderXPathet = LabelEncoder()
encodedXPathet= encoderXPathet.fit(XPathet)
encodedXPathet = encodedXPathet.transform(XPathet)
one_hot_labelsXPathet = to_categorical(encodedXPathet)
# X2_enc=encodedX2.reshape(116,1)
# Out:
# C:\Users\surya\.conda\envs\riset\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\surya\.conda\envs\riset\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
encoderXNote1 = LabelEncoder()
encodedXNote1 = encoderXNote1.fit(XNote1)
encodedXNote1 = encodedXNote1.transform(XNote1)
one_hot_labelsXNote1 = to_categorical(encodedXNote1)
# X3_enc=encodedX3.reshape(116,1)

# %%
encoderXNote2 = LabelEncoder()
encodedXNote2 = encoderXNote2.fit(XNote2)
encodedXNote2 = encodedXNote2.transform(XNote2)
one_hot_labelsXNote2 = to_categorical(encodedXNote2)
# X4_enc=encodedX4.reshape(116,1)

# %%
encoderXNote3 = LabelEncoder()
encodedXNote3 = encoderXNote3.fit(XNote3)
encodedXNote3 = encodedXNote3.transform(XNote3)
one_hot_labelsXNote3 = to_categorical(encodedXNote3)
# X5_enc=encodedX5.reshape(116,1)

# %%
encoderXNote4 = LabelEncoder()
encodedXNote4 = encoderXNote4.fit(XNote4)
encodedXNote4 = encodedXNote4.transform(XNote4)
one_hot_labelsXNote4 = to_categorical(encodedXNote4)
# X6_enc=encodedX6.reshape(116,1)

# %%
encoderYBarung1 = LabelEncoder()
encodedYBarung1= encoderYBarung1.fit(YBarung1)
encodedYBarung1 = encodedYBarung1.transform(YBarung1)
one_hot_labelsYBarung1 = to_categorical(encodedYBarung1)
#Y10_enc=encodedY10.reshape(116,1)



encoderYBarung5 = LabelEncoder()
encodedYBarung5= encoderYBarung5.fit(YBarung5)
encodedYBarung5 = encodedYBarung5.transform(YBarung5)
one_hot_labelsYBarung5 = to_categorical(encodedYBarung5)
#Y10_enc=encodedY10.reshape(116,1)



encoderYBarung9 = LabelEncoder()
encodedYBarung9= encoderYBarung9.fit(YBarung9)
encodedYBarung9 = encodedYBarung9.transform(YBarung9)
one_hot_labelsYBarung9 = to_categorical(encodedYBarung9)
#Y10_enc=encodedY10.reshape(116,1)


encoderYBarung13 = LabelEncoder()
encodedYBarung13= encoderYBarung13.fit(YBarung13)
encodedYBarung13 = encodedYBarung13.transform(YBarung13)
one_hot_labelsYBarung13 = to_categorical(encodedYBarung13)
#Y10_enc=encodedY10.reshape(116,1)



encoderYBarung17 = LabelEncoder()
encodedYBarung17= encoderYBarung17.fit(YBarung17)
encodedYBarung17 = encodedYBarung17.transform(YBarung17)
one_hot_labelsYBarung17 = to_categorical(encodedYBarung17)
#Y10_enc=encodedY10.reshape(116,1)



encoderYBarung21 = LabelEncoder()
encodedYBarung21= encoderYBarung21.fit(YBarung21)
encodedYBarung21 = encodedYBarung21.transform(YBarung21)
one_hot_labelsYBarung21 = to_categorical(encodedYBarung21)
#Y10_enc=encodedY10.reshape(116,1)


encoderYBarung25 = LabelEncoder()
encodedYBarung25= encoderYBarung25.fit(YBarung25)
encodedYBarung25 = encodedYBarung25.transform(YBarung25)
one_hot_labelsYBarung25 = to_categorical(encodedYBarung25)
#Y10_enc=encodedY10.reshape(116,1)



encoderYBarung29 = LabelEncoder()
encodedYBarung29= encoderYBarung29.fit(YBarung29)
encodedYBarung29 = encodedYBarung29.transform(YBarung29)
one_hot_labelsYBarung29 = to_categorical(encodedYBarung29)
#Y10_enc=encodedY10.reshape(116,1)

# %%
encoderYPenerus1 = LabelEncoder()
encodedYPenerus1= encoderYPenerus1.fit(YPenerus1)
encodedYPenerus1 = encodedYPenerus1.transform(YPenerus1)
one_hot_labelsYPenerus1 = to_categorical(encodedYPenerus1)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus2 = LabelEncoder()
encodedYPenerus2= encoderYPenerus2.fit(YPenerus2)
encodedYPenerus2 = encodedYPenerus2.transform(YPenerus2)
one_hot_labelsYPenerus2 = to_categorical(encodedYPenerus2)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus3 = LabelEncoder()
encodedYPenerus3= encoderYPenerus3.fit(YPenerus3)
encodedYPenerus3 = encodedYPenerus3.transform(YPenerus3)
one_hot_labelsYPenerus3 = to_categorical(encodedYPenerus3)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus4 = LabelEncoder()
encodedYPenerus4= encoderYPenerus4.fit(YPenerus4)
encodedYPenerus4 = encodedYPenerus4.transform(YPenerus4)
one_hot_labelsYPenerus4 = to_categorical(encodedYPenerus4)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus5 = LabelEncoder()
encodedYPenerus5= encoderYPenerus5.fit(YPenerus5)
encodedYPenerus5 = encodedYPenerus5.transform(YPenerus5)
one_hot_labelsYPenerus5 = to_categorical(encodedYPenerus5)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus6 = LabelEncoder()
encodedYPenerus6= encoderYPenerus6.fit(YPenerus6)
encodedYPenerus6 = encodedYPenerus6.transform(YPenerus6)
one_hot_labelsYPenerus6 = to_categorical(encodedYPenerus6)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus7 = LabelEncoder()
encodedYPenerus7= encoderYPenerus7.fit(YPenerus7)
encodedYPenerus7 = encodedYPenerus7.transform(YPenerus7)
one_hot_labelsYPenerus7 = to_categorical(encodedYPenerus7)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus8 = LabelEncoder()
encodedYPenerus8= encoderYPenerus8.fit(YPenerus8)
encodedYPenerus8 = encodedYPenerus8.transform(YPenerus8)
one_hot_labelsYPenerus8 = to_categorical(encodedYPenerus8)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus9 = LabelEncoder()
encodedYPenerus9= encoderYPenerus9.fit(YPenerus9)
encodedYPenerus9 = encodedYPenerus9.transform(YPenerus9)
one_hot_labelsYPenerus9 = to_categorical(encodedYPenerus9)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus10 = LabelEncoder()
encodedYPenerus10= encoderYPenerus10.fit(YPenerus10)
encodedYPenerus10 = encodedYPenerus10.transform(YPenerus10)
one_hot_labelsYPenerus10 = to_categorical(encodedYPenerus10)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus11 = LabelEncoder()
encodedYPenerus11= encoderYPenerus11.fit(YPenerus11)
encodedYPenerus11 = encodedYPenerus11.transform(YPenerus11)
one_hot_labelsYPenerus11 = to_categorical(encodedYPenerus11)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus12 = LabelEncoder()
encodedYPenerus12= encoderYPenerus12.fit(YPenerus12)
encodedYPenerus12 = encodedYPenerus12.transform(YPenerus12)
one_hot_labelsYPenerus12 = to_categorical(encodedYPenerus12)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus13 = LabelEncoder()
encodedYPenerus13= encoderYPenerus13.fit(YPenerus13)
encodedYPenerus13 = encodedYPenerus13.transform(YPenerus13)
one_hot_labelsYPenerus13 = to_categorical(encodedYPenerus13)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus14 = LabelEncoder()
encodedYPenerus14= encoderYPenerus14.fit(YPenerus14)
encodedYPenerus14 = encodedYPenerus14.transform(YPenerus14)
one_hot_labelsYPenerus14 = to_categorical(encodedYPenerus14)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus15 = LabelEncoder()
encodedYPenerus15= encoderYPenerus15.fit(YPenerus15)
encodedYPenerus15 = encodedYPenerus15.transform(YPenerus15)
one_hot_labelsYPenerus15 = to_categorical(encodedYPenerus15)
#Y10_enc=encodedY10.reshape(116,1)

encoderYPenerus16 = LabelEncoder()
encodedYPenerus16= encoderYPenerus16.fit(YPenerus16)
encodedYPenerus16 = encodedYPenerus16.transform(YPenerus16)
one_hot_labelsYPenerus16 = to_categorical(encodedYPenerus16)
#Y10_enc=encodedY10.reshape(116,1)

# %%
X= np.concatenate((one_hot_labelsXfungsi, one_hot_labelsXirama,one_hot_labelsXSelehBaris,one_hot_labelsXSelehAkhir,one_hot_labelsXPathet,one_hot_labelsXNote1,one_hot_labelsXNote2,one_hot_labelsXNote3,one_hot_labelsXNote4),1)

# %%
import numpy as np

from keras.layers import *
from keras.models import *



jumlahdata=len(X)
jumlahX = len(X[1])
input_dimensi = len(X[1])

output_dimensi1 = len(one_hot_labelsYBarung1[1])
output_dimensi5 = len(one_hot_labelsYBarung5[1])
output_dimensi9 = len(one_hot_labelsYBarung9[1])
output_dimensi13 = len(one_hot_labelsYBarung13[1])
output_dimensi17 = len(one_hot_labelsYBarung17[1])
output_dimensi21 = len(one_hot_labelsYBarung21[1])
output_dimensi25= len(one_hot_labelsYBarung25[1])
output_dimensi29 = len(one_hot_labelsYBarung29[1])

output2_dimensi1 = len(one_hot_labelsYPenerus1[1])
output2_dimensi2 = len(one_hot_labelsYPenerus2[1])
output2_dimensi3 = len(one_hot_labelsYPenerus3[1])
output2_dimensi4 = len(one_hot_labelsYPenerus4[1])
output2_dimensi5 = len(one_hot_labelsYPenerus5[1])
output2_dimensi6 = len(one_hot_labelsYPenerus6[1])
output2_dimensi7= len(one_hot_labelsYPenerus7[1])
output2_dimensi8 = len(one_hot_labelsYPenerus8[1])
output2_dimensi9 = len(one_hot_labelsYPenerus9[1])
output2_dimensi10 = len(one_hot_labelsYPenerus10[1])
output2_dimensi11 = len(one_hot_labelsYPenerus11[1])
output2_dimensi12 = len(one_hot_labelsYPenerus12[1])
output2_dimensi13 = len(one_hot_labelsYPenerus13[1])
output2_dimensi14 = len(one_hot_labelsYPenerus14[1])
output2_dimensi15= len(one_hot_labelsYPenerus15[1])
output2_dimensi16 = len(one_hot_labelsYPenerus16[1])


inputs = Input(shape=(None,input_dimensi))

#i = Bidirectional(LSTM(64,return_sequences=True))(inputs)
i=Bidirectional(LSTM(2, return_sequences=True))(inputs)   
i=Dropout(0.2)(i)

output1 = Dense(output_dimensi1, activation='sigmoid', name='bonangbarung1')(i)
output5 = Dense(output_dimensi5, activation='sigmoid', name='bonangbarung5')(i)
output9 = Dense(output_dimensi9, activation='sigmoid', name='bonangbarung9')(i)
output13 = Dense(output_dimensi13, activation='sigmoid', name='bonangbarung13')(i)
output17 = Dense(output_dimensi17, activation='sigmoid', name='bonangbarung17')(i)
output21 = Dense(output_dimensi21, activation='sigmoid', name='bonangbarung21')(i)
output25 = Dense(output_dimensi25, activation='sigmoid', name='bonangbarung25')(i)
output29 = Dense(output_dimensi29, activation='sigmoid', name='bonangbarung29')(i)

outputp1 = Dense(output2_dimensi1, activation='sigmoid', name='bonangpenerus1')(i)
outputp2 = Dense(output2_dimensi2, activation='sigmoid', name='bonangpenerus2')(i)
outputp3 = Dense(output2_dimensi3, activation='sigmoid', name='bonangpenerus3')(i)
outputp4 = Dense(output2_dimensi4, activation='sigmoid', name='bonangpenerus4')(i)
outputp5 = Dense(output2_dimensi5, activation='sigmoid', name='bonangpenerus5')(i)
outputp6 = Dense(output2_dimensi6, activation='sigmoid', name='bonangpenerus6')(i)
outputp7 = Dense(output2_dimensi7, activation='sigmoid', name='bonangpenerus7')(i)
outputp8 = Dense(output2_dimensi8, activation='sigmoid', name='bonangpenerus8')(i)
outputp9 = Dense(output2_dimensi9, activation='sigmoid', name='bonangpenerus9')(i)
outputp10 = Dense(output2_dimensi10, activation='sigmoid', name='bonangpenerus10')(i)
outputp11 = Dense(output2_dimensi11, activation='sigmoid', name='bonangpenerus11')(i)
outputp12 = Dense(output2_dimensi12, activation='sigmoid', name='bonangpenerus12')(i)
outputp13 = Dense(output2_dimensi13, activation='sigmoid', name='bonangpenerus13')(i)
outputp14 = Dense(output2_dimensi14, activation='sigmoid', name='bonangpenerus14')(i)
outputp15 = Dense(output2_dimensi15, activation='sigmoid', name='bonangpenerus15')(i)
outputp16 = Dense(output2_dimensi16, activation='sigmoid', name='bonangpenerus16')(i)


model = Model(inputs=inputs, outputs=[output1, output5, output9, output13, output17, output21, output25, output29, outputp1, outputp2, outputp3, outputp4, outputp5, outputp6, outputp7, outputp8, outputp9, outputp10, outputp11, outputp12, outputp13, outputp14, outputp15, outputp16])

model.compile(optimizer='adam', 
              loss={'bonangbarung1': 'binary_crossentropy','bonangbarung5': 'binary_crossentropy','bonangbarung9': 'binary_crossentropy', 'bonangbarung13': 'binary_crossentropy','bonangbarung17': 'binary_crossentropy','bonangbarung21': 'binary_crossentropy', 'bonangbarung25': 'binary_crossentropy','bonangbarung29': 'binary_crossentropy', 'bonangpenerus1': 'binary_crossentropy','bonangpenerus2': 'binary_crossentropy','bonangpenerus3': 'binary_crossentropy', 'bonangpenerus4': 'binary_crossentropy','bonangpenerus5': 'binary_crossentropy', 'bonangpenerus6': 'binary_crossentropy','bonangpenerus7': 'binary_crossentropy', 'bonangpenerus8': 'binary_crossentropy','bonangpenerus9': 'binary_crossentropy','bonangpenerus10': 'binary_crossentropy', 'bonangpenerus11': 'binary_crossentropy','bonangpenerus12': 'binary_crossentropy','bonangpenerus13': 'binary_crossentropy', 'bonangpenerus14': 'binary_crossentropy','bonangpenerus15': 'binary_crossentropy','bonangpenerus16': 'binary_crossentropy'},

              metrics={'bonangbarung1': 'accuracy','bonangbarung5': 'accuracy','bonangbarung9': 'accuracy','bonangbarung13': 'accuracy','bonangbarung17': 'accuracy','bonangbarung21': 'accuracy','bonangbarung25': 'accuracy','bonangbarung29': 'accuracy', 'bonangpenerus1': 'accuracy','bonangpenerus2': 'accuracy','bonangpenerus3': 'accuracy', 'bonangpenerus4': 'accuracy','bonangpenerus5': 'accuracy', 'bonangpenerus6': 'accuracy','bonangpenerus7': 'accuracy', 'bonangpenerus8': 'accuracy','bonangpenerus9': 'accuracy','bonangpenerus10': 'accuracy', 'bonangpenerus11': 'accuracy','bonangpenerus12': 'accuracy','bonangpenerus13': 'accuracy', 'bonangpenerus14': 'accuracy','bonangpenerus15': 'accuracy','bonangpenerus16': 'accuracy'})

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, 66)]   0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, None, 4)      1104        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 4)      0           bidirectional[0][0]
# __________________________________________________________________________________________________
# bonangbarung1 (Dense)           (None, None, 17)     85          dropout[0][0]
# __________________________________________________________________________________________________
# bonangbarung5 (Dense)           (None, None, 11)     55          dropout[0][0]
# ...

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
YBB1=one_hot_labelsYBarung1
YBB5=one_hot_labelsYBarung5
YBB9=one_hot_labelsYBarung9
YBB13=one_hot_labelsYBarung13
YBB17=one_hot_labelsYBarung17
YBB21=one_hot_labelsYBarung21
YBB25=one_hot_labelsYBarung25
YBB29=one_hot_labelsYBarung29

YBP1=one_hot_labelsYPenerus1
YBP2=one_hot_labelsYPenerus2
YBP3=one_hot_labelsYPenerus3
YBP4=one_hot_labelsYPenerus4
YBP5=one_hot_labelsYPenerus5
YBP6=one_hot_labelsYPenerus6
YBP7=one_hot_labelsYPenerus7
YBP8=one_hot_labelsYPenerus8
YBP9=one_hot_labelsYPenerus9
YBP10=one_hot_labelsYPenerus10
YBP11=one_hot_labelsYPenerus11
YBP12=one_hot_labelsYPenerus12
YBP13=one_hot_labelsYPenerus13
YBP14=one_hot_labelsYPenerus14
YBP15=one_hot_labelsYPenerus15
YBP16=one_hot_labelsYPenerus16

# %%
split = train_test_split(X, YBB1,YBB5,YBB9,YBB13,YBB17,YBB21,YBB25,YBB29,YBP1,YBP2,YBP3,YBP4,YBP5,YBP6,YBP7,YBP8,YBP9,YBP10,YBP11,YBP12,YBP13,YBP14,YBP15,YBP16,
	test_size=0.2, random_state=42)
(trainX, testX,Y_trainBB1,Y_testBB1,Y_trainBB5, Y_testBB5,Y_trainBB9, Y_testBB9,Y_trainBB13,Y_testBB13,Y_trainBB17, Y_testBB17,Y_trainBB21, Y_testBB21,Y_trainBB25, Y_testBB25,Y_trainBB29, Y_testBB29, Y_trainBP1,Y_testBP1,Y_trainBP2,Y_testBP2, Y_trainBP3,Y_testBP3,Y_trainBP4,Y_testBP4, Y_trainBP5,Y_testBP5,Y_trainBP6,Y_testBP6, Y_trainBP7,Y_testBP7,Y_trainBP8,Y_testBP8, Y_trainBP9,Y_testBP9,Y_trainBP10,Y_testBP10, Y_trainBP11,Y_testBP11,Y_trainBP12,Y_testBP12, Y_trainBP13,Y_testBP13,Y_trainBP14,Y_testBP14, Y_trainBP15,Y_testBP15,Y_trainBP16,Y_testBP16) = split

# %%
print(trainX.shape)
# Out:
# (352, 66)

# %%
trainX=trainX.reshape(352,1,66)
print(trainX.shape)
# Out:
# (352, 1, 66)

# %%
print(Y_trainBB1.shape)
print(Y_trainBB5.shape)
print(Y_trainBB9.shape)
print(Y_trainBB13.shape)
print(Y_trainBB17.shape)
print(Y_trainBB21.shape)
print(Y_trainBB25.shape)
print(Y_trainBB29.shape)
print('---')
print(Y_trainBP1.shape)
print(Y_trainBP2.shape)
print(Y_trainBP3.shape)
print(Y_trainBP4.shape)
print(Y_trainBP5.shape)
print(Y_trainBP6.shape)
print(Y_trainBP7.shape)
print(Y_trainBP8.shape)
print(Y_trainBP9.shape)
print(Y_trainBP10.shape)
print(Y_trainBP11.shape)
print(Y_trainBP12.shape)
print(Y_trainBP13.shape)
print(Y_trainBP14.shape)
print(Y_trainBP15.shape)
print(Y_trainBP16.shape)
# Out:
# (352, 17)
# (352, 11)
# (352, 15)
# (352, 9)
# (352, 17)
# (352, 10)
# (352, 14)
# (352, 10)
# ---
# (352, 11)
# (352, 9)
# (352, 16)
# (352, 3)
# (352, 11)
# (352, 12)
# (352, 9)
# (352, 8)
# (352, 16)
# (352, 9)
# (352, 12)
# (352, 4)
# (352, 15)
# (352, 12)
# (352, 10)
# (352, 10)

# %%
Y_trainBB1=Y_trainBB1.reshape(352,1,17)
Y_trainBB5=Y_trainBB5.reshape(352,1,11)
Y_trainBB9=Y_trainBB9.reshape(352,1,15)
Y_trainBB13=Y_trainBB13.reshape(352,1,9)
Y_trainBB17=Y_trainBB17.reshape(352,1,17)
Y_trainBB21=Y_trainBB21.reshape(352,1,10)
Y_trainBB25=Y_trainBB25.reshape(352,1,14)
Y_trainBB29=Y_trainBB29.reshape(352,1,10)

Y_trainBP1=Y_trainBP1.reshape(352,1,11)
Y_trainBP2=Y_trainBP2.reshape(352,1,9)
Y_trainBP3=Y_trainBP3.reshape(352,1,16)
Y_trainBP4=Y_trainBP4.reshape(352,1,3)
Y_trainBP5=Y_trainBP5.reshape(352,1,11)
Y_trainBP6=Y_trainBP6.reshape(352,1,12)
Y_trainBP7=Y_trainBP7.reshape(352,1,9)
Y_trainBP8=Y_trainBP8.reshape(352,1,8)
Y_trainBP9=Y_trainBP9.reshape(352,1,16)
Y_trainBP10=Y_trainBP10.reshape(352,1,9)
Y_trainBP11=Y_trainBP11.reshape(352,1,12)
Y_trainBP12=Y_trainBP12.reshape(352,1,4)
Y_trainBP13=Y_trainBP13.reshape(352,1,15)
Y_trainBP14=Y_trainBP14.reshape(352,1,12)
Y_trainBP15=Y_trainBP15.reshape(352,1,10)
Y_trainBP16=Y_trainBP16.reshape(352,1,10)

# %%
history = model.fit(trainX,
	{"bonangbarung1": Y_trainBB1,"bonangbarung5": Y_trainBB5, "bonangbarung9": Y_trainBB9, "bonangbarung13": Y_trainBB13, "bonangbarung17": Y_trainBB17, "bonangbarung21": Y_trainBB21, "bonangbarung25": Y_trainBB25,"bonangbarung29": Y_trainBB29,
	"bonangpenerus1": Y_trainBP1,"bonangpenerus2": Y_trainBP2, "bonangpenerus3": Y_trainBP3, "bonangpenerus4": Y_trainBP4, "bonangpenerus5": Y_trainBP5, "bonangpenerus6": Y_trainBP6, "bonangpenerus7": Y_trainBP7,"bonangpenerus8": Y_trainBP8,
	"bonangpenerus9": Y_trainBP9,"bonangpenerus10": Y_trainBP10, "bonangpenerus11": Y_trainBP11, "bonangpenerus12": Y_trainBP12, "bonangpenerus13": Y_trainBP13, "bonangpenerus14": Y_trainBP14, "bonangpenerus15": Y_trainBP15,"bonangpenerus16": Y_trainBP16},
	batch_size=5,
	epochs=100,                
	verbose=1)
# Out:
# Epoch 1/100
# ...

# %%
model.save("modelbiLSTM.h5")

# %%
print(testX.shape)
# Out:
# (88, 66)

# %%
testX=testX.reshape(88,1,66)
print(testX.shape)
# Out:
# (88, 1, 66)

# %%
print(Y_testBB1.shape)
print(Y_testBB5.shape)
print(Y_testBB9.shape)
print(Y_testBB13.shape)
print(Y_testBB17.shape)
print(Y_testBB21.shape)
print(Y_testBB25.shape)
print(Y_testBB29.shape)
print('---')
print(Y_testBP1.shape)
print(Y_testBP2.shape)
print(Y_testBP3.shape)
print(Y_testBP4.shape)
print(Y_testBP5.shape)
print(Y_testBP6.shape)
print(Y_testBP7.shape)
print(Y_testBP8.shape)
print(Y_testBP9.shape)
print(Y_testBP10.shape)
print(Y_testBP11.shape)
print(Y_testBP12.shape)
print(Y_testBP13.shape)
print(Y_testBP14.shape)
print(Y_testBP15.shape)
print(Y_testBP16.shape)
# Out:
# (88, 17)
# (88, 11)
# (88, 15)
# (88, 9)
# (88, 17)
# (88, 10)
# (88, 14)
# (88, 10)
# ---
# (88, 11)
# (88, 9)
# (88, 16)
# (88, 3)
# (88, 11)
# (88, 12)
# (88, 9)
# (88, 8)
# (88, 16)
# (88, 9)
# (88, 12)
# (88, 4)
# (88, 15)
# (88, 12)
# (88, 10)
# (88, 10)

# %%
Y_testBB1=Y_testBB1.reshape(88,1,17)
Y_testBB5=Y_testBB5.reshape(88,1,11)
Y_testBB9=Y_testBB9.reshape(88,1,15)
Y_testBB13=Y_testBB13.reshape(88,1,9)
Y_testBB17=Y_testBB17.reshape(88,1,17)
Y_testBB21=Y_testBB21.reshape(88,1,10)
Y_testBB25=Y_testBB25.reshape(88,1,14)
Y_testBB29=Y_testBB29.reshape(88,1,10)


Y_testBP1=Y_testBP1.reshape(88,1,11)
Y_testBP2=Y_testBP2.reshape(88,1,9)
Y_testBP3=Y_testBP3.reshape(88,1,16)
Y_testBP4=Y_testBP4.reshape(88,1,3)
Y_testBP5=Y_testBP5.reshape(88,1,11)
Y_testBP6=Y_testBP6.reshape(88,1,12)
Y_testBP7=Y_testBP7.reshape(88,1,9)
Y_testBP8=Y_testBP8.reshape(88,1,8)
Y_testBP9=Y_testBP9.reshape(88,1,16)
Y_testBP10=Y_testBP10.reshape(88,1,9)
Y_testBP11=Y_testBP11.reshape(88,1,12)
Y_testBP12=Y_testBP12.reshape(88,1,4)
Y_testBP13=Y_testBP13.reshape(88,1,15)
Y_testBP14=Y_testBP14.reshape(88,1,12)
Y_testBP15=Y_testBP15.reshape(88,1,10)
Y_testBP16=Y_testBP16.reshape(88,1,10)

# %%
history1 = model.fit(testX,
	{"bonangbarung1": Y_testBB1,"bonangbarung5": Y_testBB5, "bonangbarung9": Y_testBB9, "bonangbarung13": Y_testBB13, "bonangbarung17": Y_testBB17, "bonangbarung21": Y_testBB21, "bonangbarung25": Y_testBB25,"bonangbarung29": Y_testBB29,
	"bonangpenerus1": Y_testBP1,"bonangpenerus2": Y_testBP2, "bonangpenerus3": Y_testBP3, "bonangpenerus4": Y_testBP4, "bonangpenerus5": Y_testBP5, "bonangpenerus6": Y_testBP6, "bonangpenerus7": Y_testBP7,"bonangpenerus8": Y_testBP8,
	"bonangpenerus9": Y_testBP9,"bonangpenerus10": Y_testBP10, "bonangpenerus11": Y_testBP11, "bonangpenerus12": Y_testBP12, "bonangpenerus13": Y_testBP13, "bonangpenerus14": Y_testBP14, "bonangpenerus15": Y_testBP15,"bonangpenerus16": Y_testBP16},
	batch_size=5,
	epochs=100,                
	verbose=1)
# Out:
# Epoch 1/100
# ...

# %%
plt.subplot(211)
plt.plot(history.history['loss'], label='LossTraining')
plt.plot(history1.history['loss'], label='LossValidation')


plt.title('Bi-LSTM')
plt.ylabel('lost')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
plt.subplot(211)

plt.plot(history.history['bonangpenerus1_accuracy'], label='AccuracyTraining')
plt.plot(history1.history['bonangpenerus1_accuracy'], label='AccuracyValidation')

plt.title('Bi-LSTM')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
model.evaluate(testX,{"bonangbarung1": Y_testBB1,"bonangbarung5": Y_testBB5, "bonangbarung9": Y_testBB9, "bonangbarung13": Y_testBB13,"bonangbarung17": Y_testBB17,"bonangbarung21": Y_testBB21, "bonangbarung25": Y_testBB25, "bonangbarung29": Y_testBB29,
	"bonangpenerus1": Y_testBP1,"bonangpenerus2": Y_testBP2, "bonangpenerus3": Y_testBP3, "bonangpenerus4": Y_testBP4, "bonangpenerus5": Y_testBP5, "bonangpenerus6": Y_testBP6, "bonangpenerus7": Y_testBP7,"bonangpenerus8": Y_testBP8,
	"bonangpenerus9": Y_testBP9,"bonangpenerus10": Y_testBP10, "bonangpenerus11": Y_testBP11, "bonangpenerus12": Y_testBP12, "bonangpenerus13": Y_testBP13, "bonangpenerus14": Y_testBP14, "bonangpenerus15": Y_testBP15,"bonangpenerus16": Y_testBP16        
	},batch_size=4)
# Out:
# 22/22 [==============================] - 4s 4ms/step - loss: 3.6285 - bonangbarung1_loss: 0.1880 - bonangbarung5_loss: 0.1145 - bonangbarung9_loss: 0.1887 - bonangbarung13_loss: 0.1328 - bonangbarung17_loss: 0.1837 - bonangbarung21_loss: 0.1552 - bonangbarung25_loss: 0.2009 - bonangbarung29_loss: 0.1664 - bonangpenerus1_loss: 0.2289 - bonangpenerus2_loss: 0.1276 - bonangpenerus3_loss: 0.1833 - bonangpenerus4_loss: 0.0231 - bonangpenerus5_loss: 0.2412 - bonangpenerus6_loss: 0.1071 - bonangpenerus7_loss: 0.2057 - bonangpenerus8_loss: 0.0583 - bonangpenerus9_loss: 0.1944 - bonangpenerus10_loss: 0.1283 - bonangpenerus11_loss: 0.1626 - bonangpenerus12_loss: 0.0182 - bonangpenerus13_loss: 0.2087 - bonangpenerus14_loss: 0.1070 - bonangpenerus15_loss: 0.1923 - bonangpenerus16_loss: 0.1115 - bonangbarung1_accuracy: 0.2045 - bonangbarung5_accuracy: 0.7045 - bonangbarung9_accuracy: 0.2841 - bonangbarung13_accuracy: 0.7614 - bonangbarung17_accuracy: 0.1932 - bonangbarung21_accuracy: 0.6136 - bon
# ...

# %%
print(X.shape)

# %%
X=X.reshape(440,1,66)

# %%
print(YPenerus13[228])
print(encodedYPenerus13[228])

# %%
print(encodedYBarung1[0])

# %%
TBonangan1 = ["1' ","1'_",'1_ ',"2  ","2' ",'2_ ','3  ',"3' ",'31_','37_','3_ ','5  ','5_ ','6  ','6_ ','7  ','7_ ']
TBonangan5 = ['.  ',"1' ",'2  ',"2' ",'3  ',"3' ",'3_ ','5  ','5_ ','6  ','7  ']
TBonangan9 = [".  ","1' ","2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','5_ ','6  ',"6' ",'6_ ','7  ','7_ ']
TBonangan13 = [".  ","1' ","2  ","2' ",'3  ',"3' ",'5  ','6  ','6_ ']
TBonangan17 = ["1' ","1'_",'1_ ',"2  ","2' ",'2_ ','3  ',"3' ",'31_','37_','3_ ','5  ','5_ ','6  ','6_ ','7  ','7_ ']
TBonangan21 = [".  ","1' ","2  ","2' ","3  ","3' ",'3_ ','5  ','6  ','7  ']
TBonangan25 = [".  ","1' ","2  ","2' ",'3  ',"3' ",'31_','3_ ','5  ','6  ',"6' ",'6_ ','7  ','7_ ']
TBonangan29 = [".  ","1' ","2  ","2' ",'2_ ','3  ',"3' ",'5  ','6  ','7  ']

TPenerus1 = ['.  ',"1  ","1' ","2  ","2' ",'2_ ','3  ',"3' ",'5  ','5_ ','6  ']
TPenerus2 = ['.  ',"1' ","2  ","2' ",'3  ',"3' ",'5  ','6  ','7  ']
TPenerus3 = ['.  ',"1' ","1'_",'1_ ',"2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','5_ ','6  ','6_ ','7  ','7_ ']
TPenerus4 = ['.  ','5  ','6  ']
TPenerus5 = ['.  ',"1' ","2  ","2' ",'2_ ','3  ',"3' ",'5  ','5_ ','6  ','7  ']
TPenerus6 = ['.  ',"1' ","2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','6  ','6_ ','7  ']
TPenerus7 = ['.  ',"1' ","2' ",'3  ',"3' ",'5  ','5_ ','6  ','7  ']
TPenerus8 = ['.  ',"2  ","2' ",'3  ',"3' ",'5  ','6  ','7  ']
TPenerus9 = ['1  ',"1' ","1'_",'1_ ',"2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','5_ ','6  ','6_ ','7  ','7_ ']
TPenerus10 = ['.  ',"1' ","2  ","2' ",'3  ',"3' ",'5  ','6  ','7  ']
TPenerus11 = ['.  ',"1' ","2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','6  ','6_ ','7  ']
TPenerus12 = ['.  ','3  ','6  ','7  ']
TPenerus13 = ["1' ","1'_",'1_ ',"2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','5_ ','6  ','6_ ','7  ','7_ ']
TPenerus14 = ['.  ',"1' ","2  ","2' ",'2_ ','3  ',"3' ",'3_ ','5  ','6  ','6_ ','7  ']
TPenerus15 = ['.  ',"1' ","2  ","2' ",'3  ',"3' ",'5  ','6  ','7  ']
TPenerus16 = ['.  ',"1' ","2  ","2' ",'3  ',"3' ",'5  ','6  ',"6' ",'7  ']

# %%
Note1 = XNote1.flatten()
Note2 = XNote2.flatten()
Note3 = XNote3.flatten()
Note4 = XNote4.flatten()

print("Notasi Balungan   " , end=" ")
print("Notasi Bonang Barung      ", end=" ")
print("Notasi Bonang Penerus      ")
print('-----------------------------------------------------------------------------------------')
for j in range(len(X)):
    (BonangBarung1, BonangBarung5, BonangBarung9, BonangBarung13, BonangBarung17, BonangBarung21, BonangBarung25, BonangBarung29,
	BonangPenerus1,BonangPenerus2,BonangPenerus3,BonangPenerus4,BonangPenerus5,BonangPenerus6,BonangPenerus7,BonangPenerus8,
	BonangPenerus9,BonangPenerus10,BonangPenerus11,BonangPenerus12,BonangPenerus13,BonangPenerus14,BonangPenerus15,BonangPenerus16
	) = model.predict(X[[j]])
    if len(Note1[j]) == 1:
        if Note1[j] == '0':
            print('.', end=" ")
        else:
            print(Note1[j], end=" ")
    else:
        if Note1[j] == '0':
            print('.', end="")
        else:
            print(Note1[j], end="")
    if len(Note2[j]) == 1:
        if Note2[j] == '0':
            print('.', end=" ")
        else:
            print(Note2[j], end=" ")
    else:
        if Note2[j] == '0':
            print('.', end="")
        else:
            print(Note2[j], end="")
    if len(Note3[j]) == 1:
        if Note3[j] == '0':
            print('.', end=" ")
        else:
            print(Note3[j], end=" ")
    else:
        if Note3[j] == '0':
            print('.', end="")
        else:
            print(Note3[j], end="")
    if len(Note4[j]) == 1:
        if Note4[j] == '0':
            print('.', end=" ")
        else:
            print(Note4[j], end=" ")
    else:
        if Note4[j] == '0':
            print('.', end="")
        else:
            print(Note4[j], end="")
    print(' | ', end=" ")
            
    BonangBarung1= np.array(BonangBarung1)
    for y1 in BonangBarung1:
        index1 = np.argmax(list(y1))
        print((TBonangan1[index1]), end="")
        
    
    BonangBarung5= np.array(BonangBarung5)
    for y5 in BonangBarung5:
        index5 = np.argmax(list(y5))
        print((TBonangan5[index5]), end="")
    

    BonangBarung9= np.array(BonangBarung9)
    for y9 in BonangBarung9:
        index9 = np.argmax(list(y9))
        print((TBonangan9[index9]), end="")


    BonangBarung13= np.array(BonangBarung13)
    for y13 in BonangBarung13:
        index13 = np.argmax(list(y13))
        print((TBonangan13[index13]), end="")


    BonangBarung17= np.array(BonangBarung17)
    for y17 in BonangBarung17:
        index17 = np.argmax(list(y17))
        print((TBonangan17[index17]), end="")


    BonangBarung21= np.array(BonangBarung21)
    for y21 in BonangBarung21:
        index21 = np.argmax(list(y21))
        print((TBonangan21[index21]), end="")

        
    BonangBarung25= np.array(BonangBarung25)
    for y25 in BonangBarung25:
        index25 = np.argmax(list(y25))
        print((TBonangan25[index25]), end="")


    BonangBarung29= np.array(BonangBarung29)
    for y29 in BonangBarung29:
        index29 = np.argmax(list(y29))
        print((TBonangan29[index29]), end="")
           
    print('|', end=" ")
    
    BonangPenerus1= np.array(BonangPenerus1)
    for yp1 in BonangPenerus1:
        indexp1 = np.argmax(list(yp1))
        print((TPenerus1[indexp1]), end="")
    
    BonangPenerus2= np.array(BonangPenerus2)
    for yp2 in BonangPenerus2:
        indexp2 = np.argmax(list(yp2))
        print((TPenerus2[indexp2]), end="")

    BonangPenerus3= np.array(BonangPenerus3)
    for yp3 in BonangPenerus3:
        indexp3 = np.argmax(list(yp3))
        print((TPenerus3[indexp3]), end="")

    BonangPenerus4= np.array(BonangPenerus4)
    for yp4 in BonangPenerus4:
        indexp4 = np.argmax(list(yp4))
        print((TPenerus4[indexp4]), end="")
    
    BonangPenerus5= np.array(BonangPenerus5)
    for yp5 in BonangPenerus5:
        indexp5 = np.argmax(list(yp5))
        print((TPenerus5[indexp5]), end="")

    BonangPenerus6= np.array(BonangPenerus6)
    for yp6 in BonangPenerus6:
        indexp6 = np.argmax(list(yp6))
        print((TPenerus6[indexp6]), end="")
        
    BonangPenerus7= np.array(BonangPenerus7)
    for yp7 in BonangPenerus7:
        indexp7 = np.argmax(list(yp7))
        print((TPenerus7[indexp7]), end="")
    
    BonangPenerus8= np.array(BonangPenerus8)
    for yp8 in BonangPenerus8:
        indexp8 = np.argmax(list(yp8))
        print((TPenerus8[indexp8]), end="")

    BonangPenerus9= np.array(BonangPenerus9)
    for yp9 in BonangPenerus9:
        indexp9 = np.argmax(list(yp9))
        print((TPenerus9[indexp9]), end="")
    
    BonangPenerus10= np.array(BonangPenerus10)
    for yp10 in BonangPenerus10:
        indexp10 = np.argmax(list(yp10))
        print((TPenerus10[indexp10]), end="")

    BonangPenerus11= np.array(BonangPenerus11)
    for yp11 in BonangPenerus11:
        indexp11 = np.argmax(list(yp11))
        print((TPenerus11[indexp11]), end="")

    BonangPenerus12= np.array(BonangPenerus12)
    for yp12 in BonangPenerus12:
        indexp12 = np.argmax(list(yp12))
        print((TPenerus12[indexp12]), end="")
    
    BonangPenerus13= np.array(BonangPenerus13)
    for yp13 in BonangPenerus13:
        indexp13 = np.argmax(list(yp13))
        print((TPenerus13[indexp13]), end="")

    BonangPenerus14= np.array(BonangPenerus14)
    for yp14 in BonangPenerus14:
        indexp14 = np.argmax(list(yp14))
        print((TPenerus14[indexp14]), end="")
        
    BonangPenerus15= np.array(BonangPenerus15)
    for yp15 in BonangPenerus15:
        indexp15 = np.argmax(list(yp15))
        print((TPenerus15[indexp15]), end="")
    
    BonangPenerus16= np.array(BonangPenerus16)
    for yp16 in BonangPenerus16:
        indexp16 = np.argmax(list(yp16))
        print((TPenerus16[indexp16]), end="")

    print()

# %%
import pandas as pd
def ReadDataTest(sf):
    print("Baca file :",sf)
    df = pd.read_csv(sf,header=None)
    df = np.array(df)
    XfungsiT = df[2:,1:2]
    XiramaT = df[2:,2:3]
    XSelehBarisT = df[2:,14:15]
    XSelehAkhirT = df[2:,15:16]
    XPathetT = df[2:,16:17]

    XgatraT = df[2:,4:5]
    XNote1T = df[2:,5:6]
    XNote2T = df[2:,7:8]
    XNote3T = df[2:,9:10]
    XNote4T = df[2:,11:12]
    

    return XfungsiT,XiramaT,XSelehBarisT,XSelehAkhirT,XPathetT,XgatraT,XNote1T,XNote2T,XNote3T,XNote4T

# %%
sf='databinerDataTest.csv'
XfungsiT,XiramaT,XSelehBarisT,XSelehAkhirT,XPathetT,XgatraT,XNote1T,XNote2T,XNote3T,XNote4T=ReadDataTest(sf)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

encoderXfungsiT = LabelEncoder()
encodedXfungsiT = encoderXfungsiT.fit(XfungsiT)
encodedXfungsiT = encodedXfungsiT.transform(XfungsiT)
one_hot_labelsXfungsiT = to_categorical(encodedXfungsiT)


encoderXiramaT = LabelEncoder()
encodedXiramaT = encoderXiramaT.fit(XiramaT)
encodedXiramaT = encodedXiramaT.transform(XiramaT)
one_hot_labelsXiramaT = to_categorical(encodedXiramaT)

encoderXSelehBarisT = LabelEncoder()
encodedXSelehBarisT = encoderXSelehBarisT.fit(XSelehBarisT)
encodedXSelehBarisT = encodedXSelehBarisT.transform(XSelehBarisT)
one_hot_labelsXSelehBarisT= to_categorical(encodedXSelehBarisT)
# X2_enc=encodedX2.reshape(116,1)

encoderXSelehAkhirT = LabelEncoder()
encodedXSelehAkhirT = encoderXSelehAkhirT.fit(XSelehAkhirT)
encodedXSelehAkhirT = encodedXSelehAkhirT.transform(XSelehAkhirT)
one_hot_labelsXSelehAkhirT = to_categorical(encodedXSelehAkhirT)
# X2_enc=encodedX2.reshape(116,1)

encoderXPathetT = LabelEncoder()
encodedXPathetT= encoderXPathetT.fit(XPathetT)
encodedXPathetT = encodedXPathetT.transform(XPathetT)
one_hot_labelsXPathetT = to_categorical(encodedXPathetT)
# X2_enc=encodedX2.reshape(116,1)



encoderXNote1T = LabelEncoder()
encodedXNote1T = encoderXNote1T.fit(XNote1T)
encodedXNote1T = encodedXNote1T.transform(XNote1T)
one_hot_labelsXNote1T = to_categorical(encodedXNote1T)

encoderXNote2T = LabelEncoder()
encodedXNote2T = encoderXNote2T.fit(XNote2T)
encodedXNote2T = encodedXNote2T.transform(XNote2T)
one_hot_labelsXNote2T = to_categorical(encodedXNote2T)

encoderXNote3T = LabelEncoder()
encodedXNote3T = encoderXNote3T.fit(XNote3T)
encodedXNote3T = encodedXNote3T.transform(XNote3T)
one_hot_labelsXNote3T = to_categorical(encodedXNote3T)

encoderXNote4T = LabelEncoder()
encodedXNote4T = encoderXNote4T.fit(XNote4T)
encodedXNote4T = encodedXNote4T.transform(XNote4T)
one_hot_labelsXNote4T = to_categorical(encodedXNote4T)

# %%
XTest= np.concatenate((one_hot_labelsXfungsiT,one_hot_labelsXiramaT,one_hot_labelsXSelehBarisT,one_hot_labelsXSelehAkhirT,one_hot_labelsXPathetT,one_hot_labelsXNote1T,one_hot_labelsXNote2T,one_hot_labelsXNote3T,one_hot_labelsXNote4T),1)

# %%
print(XTest.shape)

# %%
XTest=XTest.reshape(488,1,66)

# %%
GatraT = XgatraT.flatten()
Note1T = XNote1T.flatten()
Note2T = XNote2T.flatten()
Note3T = XNote3T.flatten()
Note4T = XNote4T.flatten()

baris =12
birama = 4
k=1
l=1
b=1

print('balungan')
for j in range(birama*baris):

    if j==48:
        break
    if len(Note1T[j]) == 1:
        if Note1T[j] == '0':
            print('.', end="   ")
        else:
            print(Note1T[j], end="   ")
    else:
        print(Note1T[j], end="  ")

    if len(Note2T[j]) == 1:
        if Note2T[j] == '0':
            print('.', end="   ")
        else:
            print(Note2T[j], end="   ")
    else:
        print(Note2T[j], end="  ")

    if len(Note3T[j]) == 1:
        if Note3T[j] == '0':
            print('.', end="   ")
        else:
            print(Note3T[j], end="   ")
    else:
        print(Note3T[j], end="  ")

    if len(Note4T[j]) == 1:
        if Note4T[j] == '0':
            print('.', end="   ")
        else:
            print(Note4T[j], end="   ")
    else:
        print(Note4T[j], end="  ")

    if j == b*birama-1 :
        print()
        b=b+1

print()
print('bonang barung dan penerus')
b = 1
for k in range(birama*baris):
    
    (BonangBarung1, BonangBarung5, BonangBarung9, BonangBarung13, BonangBarung17, BonangBarung21, BonangBarung25, BonangBarung29,
	BonangPenerus1,BonangPenerus2,BonangPenerus3,BonangPenerus4,BonangPenerus5,BonangPenerus6,BonangPenerus7,BonangPenerus8,
	BonangPenerus9,BonangPenerus10,BonangPenerus11,BonangPenerus12,BonangPenerus13,BonangPenerus14,BonangPenerus15,BonangPenerus16
	)= model.predict(XTest[[k]])

    BonangBarung1= np.array(BonangBarung1)
    for y1 in BonangBarung1:
        index1 = np.argmax(list(y1))
        print((TBonangan1[index1]), end="")
        
    
    BonangBarung5= np.array(BonangBarung5)
    for y5 in BonangBarung5:
        index5 = np.argmax(list(y5))
        print((TBonangan5[index5]), end="")
    

    BonangBarung9= np.array(BonangBarung9)
    for y9 in BonangBarung9:
        index9 = np.argmax(list(y9))
        print((TBonangan9[index9]), end="")


    BonangBarung13= np.array(BonangBarung13)
    for y13 in BonangBarung13:
        index13 = np.argmax(list(y13))
        print((TBonangan13[index13]), end="")


    BonangBarung17= np.array(BonangBarung17)
    for y17 in BonangBarung17:
        index17 = np.argmax(list(y17))
        print((TBonangan17[index17]), end="")


    BonangBarung21= np.array(BonangBarung21)
    for y21 in BonangBarung21:
        index21 = np.argmax(list(y21))
        print((TBonangan21[index21]), end="")

        
    BonangBarung25= np.array(BonangBarung25)
    for y25 in BonangBarung25:
        index25 = np.argmax(list(y25))
        print((TBonangan25[index25]), end="")


    BonangBarung29= np.array(BonangBarung29)
    for y29 in BonangBarung29:
        index29 = np.argmax(list(y29))
        print((TBonangan29[index29]), end="")
           
    print('|', end=" ")
  
    BonangPenerus1= np.array(BonangPenerus1)
    for yp1 in BonangPenerus1:
        indexp1 = np.argmax(list(yp1))
        print((TPenerus1[indexp1]), end="")
    
    BonangPenerus2= np.array(BonangPenerus2)
    for yp2 in BonangPenerus2:
        indexp2 = np.argmax(list(yp2))
        print((TPenerus2[indexp2]), end="")

    BonangPenerus3= np.array(BonangPenerus3)
    for yp3 in BonangPenerus3:
        indexp3 = np.argmax(list(yp3))
        print((TPenerus3[indexp3]), end="")

    BonangPenerus4= np.array(BonangPenerus4)
    for yp4 in BonangPenerus4:
        indexp4 = np.argmax(list(yp4))
        print((TPenerus4[indexp4]), end="")
    
    BonangPenerus5= np.array(BonangPenerus5)
    for yp5 in BonangPenerus5:
        indexp5 = np.argmax(list(yp5))
        print((TPenerus5[indexp5]), end="")
        

    BonangPenerus6= np.array(BonangPenerus6)
    for yp6 in BonangPenerus6:
        indexp6 = np.argmax(list(yp6))
        print((TPenerus6[indexp6]), end="")
        
    BonangPenerus7= np.array(BonangPenerus7)
    for yp7 in BonangPenerus7:
        indexp7 = np.argmax(list(yp7))
        print((TPenerus7[indexp7]), end="")
    
    BonangPenerus8= np.array(BonangPenerus8)
    for yp8 in BonangPenerus8:
        indexp8 = np.argmax(list(yp8))
        print((TPenerus8[indexp8]), end="")

    BonangPenerus9= np.array(BonangPenerus9)
    for yp9 in BonangPenerus9:
        indexp9 = np.argmax(list(yp9))
        print((TPenerus9[indexp9]), end="")
    
    BonangPenerus10= np.array(BonangPenerus10)
    for yp10 in BonangPenerus10:
        indexp10 = np.argmax(list(yp10))
        print((TPenerus10[indexp10]), end="")

    BonangPenerus11= np.array(BonangPenerus11)
    for yp11 in BonangPenerus11:
        indexp11 = np.argmax(list(yp11))
        print((TPenerus11[indexp11]), end="")

    BonangPenerus12= np.array(BonangPenerus12)
    for yp12 in BonangPenerus12:
        indexp12 = np.argmax(list(yp12))
        print((TPenerus12[indexp12]), end="")
    
    BonangPenerus13= np.array(BonangPenerus13)
    for yp13 in BonangPenerus13:
        indexp13 = np.argmax(list(yp13))
        print((TPenerus13[indexp13]),end="")
        

    BonangPenerus14= np.array(BonangPenerus14)
    for yp14 in BonangPenerus14:
        indexp14 = np.argmax(list(yp14))
        print((TPenerus14[indexp14]), end="")
        
    BonangPenerus15= np.array(BonangPenerus15)
    for yp15 in BonangPenerus15:
        indexp15 = np.argmax(list(yp15))
        print((TPenerus15[indexp15]), end="")
    
    BonangPenerus16= np.array(BonangPenerus16)
    for yp16 in BonangPenerus16:
        indexp16 = np.argmax(list(yp16))
        print((TPenerus16[indexp16]), end="")
    print()

if k == b*birama-1:
        print()
        b=b+1

# %%
pip install librosa

# %%
pip install dtw

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from dtw import dtw
from numpy.linalg import norm

#Loading audio files
y1, sr1 = librosa.load('AB.wav') 
y2, sr2 = librosa.load('AC.wav') 
y3, sr3 = librosa.load('AD.wav') 
y4, sr4 = librosa.load('AE.wav')

# %%
#Showing multiple plots using subplot
plt.subplot(1, 2, 1) 
mfcc1 = librosa.feature.mfcc(y1,sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)



plt.show()  #To display the plots graphically

# %%
plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)
plt.show()

# %%
plt.subplot(1, 2, 2)
mfcc3 = librosa.feature.mfcc(y3, sr3)
librosa.display.specshow(mfcc3)
plt.show()

# %%
plt.subplot(1, 2, 2)
mfcc4 = librosa.feature.mfcc(y4, sr4)
librosa.display.specshow(mfcc4)
plt.show()

# %%
#dist, cost, path = dtw(mfcc1.T, mfcc2.T)
dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest')
plt.plot(path[0], path[1], 'w')   #creating plot for DTW
plt.show()

# %%
#dist, cost, path = dtw(mfcc1.T, mfcc2.T)
dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc3.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest')
plt.plot(path[0], path[1], 'w')   #creating plot for DTW
plt.show()

# %%
#dist, cost, path = dtw(mfcc1.T, mfcc2.T)
dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc4.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest')
plt.plot(path[0], path[1], 'w')   #creating plot for DTW
plt.show()

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
x1, sr1 = librosa.load('AB.wav') 

# Spectrogram of frequency
X = librosa.stft(x1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(15, 3))
librosa.display.specshow(Xdb, sr=sr1, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
x1, sr1 = librosa.load('AC.wav') 

# Spectrogram of frequency
X = librosa.stft(x1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(15, 3))
librosa.display.specshow(Xdb, sr=sr1, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
x1, sr1 = librosa.load('AD.wav') 

# Spectrogram of frequency
X = librosa.stft(x1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(15, 3))
librosa.display.specshow(Xdb, sr=sr1, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
x1, sr1 = librosa.load('AE.wav') 

# Spectrogram of frequency
X = librosa.stft(x1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(15, 3))
librosa.display.specshow(Xdb, sr=sr1, x_axis='time', y_axis='hz')
plt.colorbar()
